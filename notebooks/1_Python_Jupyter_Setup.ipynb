# %%
# Notebook 1 - Python & Jupyter Setup
# 


# Bibliograpy 
# https://github.com/karpathy/micrograd
# make your own runpod / paperspace
# learn karpathy llm  from scratch - https://www.youtube.com/watch?v=kCc8FmEb1nY&t=393s

#https://github.com/adnanwahab/nn-zero-to-hero

# %%
#import fs of remote_machine

#Username: 9g70y70yhmmp1fg9gea1
#Password: sykmeuf51k0873qujrlp


# https://github.com/zed-industries/extensions/pull/1511
# robots need to predict next action for nanosaur for each agent



# https://zed.dev/docs/getting-started

# %%
# Complete as much as possible in 10 days

# https://modal.com/apps/adnanwahab/main
# https://app.hex.tech/82f53ad5-33e8-4b80-98b1-29b1b1f428b6/hex/00ba1ff7-b947-4b1c-b6ca-97d6e0a4e008/draft/logic

# auto-work https://github.com/dusty-nv/jetson-containers
# https://github.com/dusty-nv/jetson-inference
# https://github.com/cloudflare/cloudflared
# https://pola.rs/
# https://developers.cloudflare.com/d1/
# https://modal.com/apps/adnanwahab/main

# %%
! pip install redis

# %%
# Playwright snapshot test chatGPT and index it before it deletes it!!

# Storage
import redis

def init_upstash_redis():
    
    # Replace these with your actual values from the Upstash console
    host = "c9d22cc9-79fa-462e-8a4c-a9dfaeb06780-<region>.upstash.io"  
    port = 12345  # Example port
    username = "default"
    password = "YOUR_UPSTASH_REDIS_PASSWORD"
    
    # Create a Redis client with SSL
    r = redis.Redis(
        host=host,
        port=port,
        username=username,
        password=password,
        ssl=True,
        ssl_cert_reqs=None
    )
    return r

def init_supabase():
    url = 'user=postgres.ewkxvbgbzikwwudriebh password=[YOUR-PASSWORD] host=aws-0-us-west-1.pooler.supabase.com port=6543 dbname=postgres'
    return supabsase
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 4
#       1 # Playwright snapshot test chatGPT and index it before it deletes it!!
#       2
#       3 # Storage
# ----> 4 import redis
#       6 def init_upstash_redis():
#       7
#       8     # Replace these with your actual values from the Upstash console
#       9     host = "c9d22cc9-79fa-462e-8a4c-a9dfaeb06780-<region>.upstash.io"
#
# ModuleNotFoundError: No module named 'redis'

# %%
def try_redis():
    redis = init_upstash_redis()
    # Set a key
    r.set("mykey", "myvalue")
    
    # Retrieve the value
    value = r.get("mykey")
    print(value)  # Should print: b'myvalue'

try_redis()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 10
#       7     value = r.get("mykey")
#       8     print(value)  # Should print: b'myvalue'
# ---> 10 try_redis()
#
# Cell In[34], line 2, in try_redis()
#       1 def try_redis():
# ----> 2     redis = init_upstash_redis()
#       3     # Set a key
#       4     r.set("mykey", "myvalue")
#
# Cell In[32], line 6, in init_upstash_redis()
#       5 def init_upstash_redis():
# ----> 6     import redis
#       8     # Replace these with your actual values from the Upstash console
#       9     host = "c9d22cc9-79fa-462e-8a4c-a9dfaeb06780-<region>.upstash.io"
#
# ModuleNotFoundError: No module named 'redis'

# %%
Creative_AI = [
    'descript',
    'dreamscape'
]

Agentic_UI = [
    'laminar',
    'waymo',
    'flirtflow',
    'jeff_heer'
]
